# %% [markdown]
# # Chapter 7 Moving Beyond Linearity
#
# ## Exercise 1
# ### 1.a
# Since $\forall x \leq \xi$, $(x - \xi)_+^3 = 0$. So, when $x \leq \xi$, $f(x) = \beta_0 + \beta_1x + \beta_2x^2 + \beta_3x^3$.
#
# Since $\forall x \leq \xi \text{, } f(x) = f_1(x)$, it follows that: $$\beta_0 + \beta_1x + \beta_2x^2 + \beta_3x^3 = a_1 + b_1x + c_1x^2 + d_1x^3$$
# So, $\forall x \leq \xi \text{, } a_1 = \beta_0$, $b_1 = \beta_1$, $c_1 = \beta_2$, $d_1 = \beta_3$.
#
# ### 1.b
# Since $\forall x > \xi$, $(x - \xi)_+^3 = (x - \xi)^3 = x^3 - 3x^2\xi + 3x\xi^2 - \xi^3$. So, when $x > \xi$, $$f(x) = \beta_0 + \beta_1x + \beta_2x^2 + \beta_3x^3 + \beta_4(x^3 - 3x^2\xi + 3x\xi^2 - \xi^3)$$.
# $$f(x) = (\beta_0 - \beta_4\xi^3) + (\beta_1 + 3\beta_4\xi^2)x + (\beta_2 - 3\beta_4\xi)x^2 + (\beta_3 + \beta_4)x^3$$
#
# Since $\forall x > \xi \text{, } f(x) = f_2(x)$, it follows that: $a_2 = \beta_0 - \beta_4\xi^3$, $b_2 = \beta_1 + 3\beta_4\xi^2$, $c_2 = \beta_2 - 3\beta_4\xi$, $d_2 = \beta_3 + \beta_4$.
#
# ### 1.c
# Given (a), for $f_1(x)$:
# $$f_1(\xi) = a_1 + b_1\xi + c_1\xi^2 + d_1\xi^3$$
# $$f_1(\xi) = \beta_0 + \beta_1\xi + \beta_2\xi^2 + \beta_3\xi^3$$
#
# Given (b), for $f_2(x)$:
# $$f_2(\xi) = a_2 + b_2\xi + c_2\xi^2 + d_2\xi^3$$
# $$f_2(\xi) = (\beta_0 - \beta_4\xi^3) + (\beta_1 + 3\beta_4\xi^2)\xi + (\beta_2 - 3\beta_4\xi)\xi^2 + (\beta_3 + \beta_4)\xi^3$$
# $$f_2(\xi) = \beta_0 + (-\beta_4\xi^3 + 3\beta_4\xi^3 - 3\beta_4\xi^3 + \beta_4\xi^3) + \beta_1\xi + \beta_2\xi^2 + \beta_3\xi^3$$
# $$f_2(\xi) = \beta_0 + \beta_1\xi + \beta_2\xi^2 + \beta_3\xi^3$$
#
# So, $f_1(\xi) = f_2(\xi)$. So, $f(x)$ is continuous at $\xi$.
#
# ### 1.d
# For $f_1(x)$:
# $$f_1'(x) = \beta_1 + 2\beta_2x + 3\beta_3x^2$$
# $$f_1'(\xi) = \beta_1 + 2\beta_2\xi + 3\beta_3\xi^2$$
#
# For $f_2(x)$:
# $$f_2'(x) = (\beta_1 + 3\beta_4\xi^2) + 2(\beta_2 - 3\beta_4\xi)x + 3(\beta_3 + \beta_4)x^2$$
# $$f_2'(\xi) = \beta_1 + (3\beta_4\xi^2 - 6\beta_4\xi^2 + 3\beta_4\xi^2) + 2\beta_2\xi + 3\beta_3\xi^2$$
# $$f_2'(\xi) = \beta_1 + \beta_2\xi + \beta_3\xi^2$$
#
# So, $f_1'(\xi) = f_2'(\xi)$. So, $f'(x)$ is continuous at $\xi$.
#
# ### 1.e
#
# For $f_1(x)$:
# $$f_1''(x) = 2\beta_2 + 6\beta_3x$$
# $$f_1''(\xi) = 2\beta_2 + 6\beta_3\xi$$
#
# For $f_2(x)$:
# $$f_2''(x) = 2(\beta_2 - 3\beta_4\xi) + 6(\beta_3 + \beta_4)x$$
# $$f_2''(\xi) = 2(\beta_2 - 3\beta_4\xi) + 6(\beta_3 + \beta_4)\xi$$
# $$f_2''(\xi) = 2\beta_2 + (-6\beta_4\xi + 6\beta_4\xi) + 6\beta_3\xi$$
# $$f_2''(\xi) = 2\beta_2 + 6\beta_3\xi$$
#
# So, $f_1''(\xi) = f_2''(\xi)$. So, $f''(x)$ is continuous at $\xi$.
#
# From (c), (d), (e), it follows that $f(x)$ is a cubic spline.
#
# ## Exercise 2
# The objective function for $\hat{g}$ is:
# $$ \hat{g} = \arg \min_g \left( \sum (y_i - g(x_i))^2 + \lambda \int [g^{(m)}(x)]^2 dx \right) $$
# where $g^{(m)}(x)$ represents the $m\text{th}$ derivatives of $g$.
#
# $\lambda = \infty$ indicates that the penalty term $\lambda \int [g^{(m)}(x)]^2 dx$ dominates. To minimize the objective function, the penalty term should approach 0: $$\lambda \int [g^{(m)}(x)]^2 dx \approx 0$$
#
# This implies that the $m\text{th}$ derivative $g^{(m)}(x) = 0$
#
# ### 2.a
#
# For $m = 0$, $g^{(m)}(x) = g(x) = 0$.
#
# So, the graph of $\hat{g}(x)$ is a horizontal line at $y=0$
#
#
# ### 2.b
# For $m = 1$, $g^{(1)}(x) = g'(x) = 0$. This implies that $g(x) = c$, where $c$ is the mean of $y$
#
# So, the graph of $\hat{g}(x)$ is a horizontal line at the mean of $y$.
#
# ### 2.c
# For $m = 2$, $g^{(2)}(x) = g''(x) = 0$. This implies that $g(x) = c_0 + c_1x$.
#
# So, the graph of $\hat{g}(x)$ is a least squares regression straight line.
#
# ### 2.d
# For $m = 3$, $g^{(3)}(x) = g'''(x) = 0$. This implies that $g(x) = c_0 + c_1x + c_2x^2$.
#
# So, the graph of $\hat{g}(x)$ is a quadratic curve (parabola).
#
# ### 2.f
# $\lambda = 0$ implies that the penalty term is canceled from the objective function. So, to minimize the objective function, the error term needs to be minimized. To achieve this, $\hat{g}$ interpolates the values of $y$.
#
# So, the graph of $\hat{g}(x)$ is an curve that passes through every data point.
#
# ## Exercise 3

# %%
import numpy as np
import matplotlib.pyplot as plt

rng = np.random.default_rng(0)
X = rng.uniform(-2, 2, 100)
betas = np.array([1, 1, -2])
I = np.where(X >= 1, 1, 0)
Y = betas[0] + betas[1]*X + betas[2]* (X - 1)**2 * I + rng.normal(0, 0.5, X.shape[0])

X_draw = np.linspace(X.min(), X.max(), 100)
I_draw = np.where(X_draw >= 1, 1, 0)
Y_draw = betas[0] + betas[1]*X_draw + betas[2]* (X_draw - 1)**2 * I_draw

fig, ax = plt.subplots()
ax.scatter(X, Y, facecolor='gray', alpha=0.5)
ax.plot(X_draw[I_draw == 1], Y_draw[I_draw == 1], color='red', label=r'$X \geq 1$')
ax.plot(X_draw[I_draw == 0], Y_draw[I_draw == 0], color='blue', label=r'$X < 1$')
ax.axvline(x=1, color='black', linestyle='--')
ax.legend();

# %% [markdown]
# ## Exercise 4

# %%
# 4
X = rng.uniform(-2, 6, 100)
betas = np.array([1, 1, 3])
I_0 = np.where((0 <= X) & (X <= 2), 1, 0)
I_1 = np.where((1 <= X) & (X <= 2), 1, 0)
I_2 = np.where((3 <= X) & (X <= 4), 1, 0)
I_3 = np.where((4 <= X) & (X <= 5), 1, 0)
Y = betas[0] + betas[1] * (I_0 - (X-1) * I_1) + betas[2] * ((X-3) * I_2 + I_3) + rng.normal(0, 1, 100)

X_draw = np.linspace(X.min(), X.max(), 100)
I_0_draw = np.where((0 <= X_draw) & (X_draw <= 2), 1, 0)
I_1_draw = np.where((1 <= X_draw) & (X_draw <= 2), 1, 0)
I_2_draw = np.where((3 <= X_draw) & (X_draw <= 4), 1, 0)
I_3_draw = np.where((4 <= X_draw) & (X_draw <= 5), 1, 0)
Y_draw = betas[0] + betas[1] * (I_0_draw - (X_draw-1) * I_1_draw) + betas[2] * ((X_draw-3) * I_2_draw + I_3_draw)

fig, ax = plt.subplots()

ax.scatter(X, Y, facecolor='gray', alpha=0.5)
ax.plot(X_draw, Y_draw, color='red');

# %% [markdown]
# ## Exercise 5
# The objective function for $\hat{g}$ is:
# $$ \hat{g}_1 = \arg \min_g \left( \sum (y_i - g(x_i))^2 + \lambda \int [g^{(3)}(x)]^2 dx \right) $$
# $$ \hat{g}_2 = \arg \min_g \left( \sum (y_i - g(x_i))^2 + \lambda \int [g^{(4)}(x)]^2 dx \right) $$
# where $g^{(m)}(x)$ represents the $m\text{th}$ derivatives of $g$.
#
# For both $\hat{g}_1$ and $\hat{g}_2$, the objective function is a $RSS$ plus a penalty term that penalizes the third and fourth derivatives of $g$ respectively.
#
# $\lambda$ is a regularization parameter that controls the smoothness of $g$. The higher the value of $\lambda$, the more the penalty term dominates the objective function, leading to a smoother $g$ as $g$ is forced to change less. Reversely, the lower the value of $\lambda$, the more the $RSS$ dominates the objective function, leading to a more wiggly $g$ as $g$ simply interpolates the data to minimize $RSS$.
#
# ### 5.a
# As $\lambda \rightarrow \infty$, the penalty term in $\hat{g}_1$ and $\hat{g}_2$ dominates the objective function, forcing the change in $\hat{g}_1$ and $\hat{g}_2$ to be minimal. For the objective function to be minimum:
# * For $\hat{g}_1$, $\forall x, g^{(3)}(x) = 0$. This implies that, $\hat{g}_1 = a_1 + b_1x + c_1x^2$. So, $\hat{g}_1$ is a quadratic function.
# * For $\hat{g}_2$, $\forall x, g^{(4)}(x) = 0$. This implies that, $\hat{g}_2 = a_2 + b_2x + c_2x^2 + d_2x^3$. So, $\hat{g}_2$ is a cubic function.
#
# Given the polynomial forms of $\hat{g}_1$ and $\hat{g}_2$, since $\hat{g}_1$ has a degree 2 and $\hat{g}_2$ has a degree 3, $\hat{g}_1$ has less flexibility than $\hat{g}_2$, thus $\hat{g}_1$ has higher bias but lower variance than $\hat{g}_2$. So, $\hat{g}_2$ is more likely to fit the training data better than $\hat{g}_1$ as the model has more degrees of freedom, it might overfit to fit the noise in the training data. So, $\hat{g}_2$ is more likely to have a lower training RSS than $\hat{g}_1$.
#
# ### 5.b
# For unseen test data, whether $\hat{g}_1$ or $\hat{g}_2$ performs better depends on the true relationship between the predictors and response:
# * If the true relationship is closer to a quadratic function (e.g linear or quadratic), then $\hat{g}_1$ is more likely to have lower test RSS. As $\hat{g}_2$ has higher flexibility, and thus higher variance, than $\hat{g}_1$, it might overfit to fit the noise in the training data, leading to a poor generalization to unseen data, thus higher test RSS.
# * If the true relationship is closer to a cubic function, then $\hat{g}_2$ is more likely to have lower test RSS. As $\hat{g}_1$ has lower flexibility, it might be too rigid, thus having higher bias, to capture the curvature in the data than $\hat{g}_2$. As $\hat{g}_2$ has more degree of freedoms to capture the true relationship in the data, it has lower bias than $\hat{g}_1$. Therefore, as it is able to better capture the relationship in the data, $\hat{g}_2$ is more likely to perform better on test data, thus having lower test RSS.
#
# ### 5.c
# As $\lambda = 0$, the penalty term in the objective function is minimized, leaving $RSS$ to dominate. The objective function of $\hat{g}_1$ and $\hat{g}_2$ is then equal and is dominated only by the $RSS$.
# $$\hat{g}_1 = \hat{g}_2 = \arg \min_g \left( \sum (y_i - g(x_i))^2 \right)$$
# In this case, $\hat{g}_1$ and $\hat{g}_2$ are identical to each other. These two models simply interpolates the data to minimize $RSS$. So, their training and test RSS are the same.

# %%
import random
random.seed(0)

from IPython.display import display

import numpy as np, pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from ISLP import load_data
from ISLP.models import (summarize, poly, ModelSpec as MS)
from statsmodels.stats.anova import anova_lm

from sklearn.model_selection import cross_val_score, KFold, cross_validate
from sklearn.preprocessing import PolynomialFeatures, OneHotEncoder, LabelEncoder, SplineTransformer
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from pygam import (s as s_gam,
l as l_gam,
f as f_gam,
LinearGAM,
LogisticGAM)

from ISLP.transforms import (BSpline, NaturalSpline)
from ISLP.models import bs, ns
from ISLP.pygam import (approx_lam,
degrees_of_freedom,
plot as plot_gam,
anova as anova_gam)

# %% [markdown]
# ## Exercise 6
#
# ### 6.a
# Using 5-fold cross-validation, the optimal degree with the lowest cross-validated MSE is $d=4$. This is shown in the plot *CV error by polynomial degree*. The plot shows that from $d=1$ to $d=2$, there is a drastic decrease of 75 units of MSE. From $d=2$ to $d=10$, the fluctutation in CV MSE is within 5 units of MSE. While the minimum CV MSE is at $d=4$, the decrease in CV MSE from $d=3$ to $d=4$ is rather minimal. The CV MSE result implies that a quartic polynomial is the model with the best predictive power, and a cubic polynomial is sufficiently good compared to a quartic polynomial.
#
# Using ANOVA, the optimal degree is $d=3$. This is shown in the *ANOVA table*. The gain in F-value as $d=1$ to $d=2$ is the highest, 143.519 with a significantly low p-value $\left(p << 0.05 \right)$. This implies a significant increase in the model's explanatory power. As $d=2$ to $d=3$, the increase in F-value is still significant, 9.884 with a p-value $\left(p << 0.05 \right)$. This implies that moving from a quadratic to cubic polynomial significantly increases the model's explanatory power. From $d=3$ to $d=10$, the increase in F-value decreases, p-value $\left(p > 0.05 \right)$. Moving from $d=3$ to $d=4$, the p-value is around 0.05111, which borders the threshold 0.05.This implies that moving from a cubic to quartic polynomial doesn't significantly increase the model's explanatory power.
#
# The results show that the optimal degree for model's predictive power is $d=4$ while the optimal degree for model's explanatory power is $d=3$. The two results show that a cubic model is sufficient enough for both predictive and explanatory power, since the gain in predictive power from cubic to quartic is rather minimal.

# %%
Wage = load_data('Wage')

X = Wage['age'].values.reshape(-1, 1)
y = Wage['wage'].values.reshape(-1, 1)

degrees = range(1, 11)
cv_scores = []
cv = KFold(n_splits=5,
           shuffle=True,
           random_state=0)
# perform 5 fold cross validation for each degree
for degree in degrees:
    model = Pipeline([
        ('poly', PolynomialFeatures(degree=degree)),
        ('linear', LinearRegression())
    ])
    scores = cross_val_score(model, X, y, cv=cv, scoring='neg_mean_squared_error')
    cv_scores.append(-scores.mean())

# fit models with statsmodels for ANOVA
models = []
for degree in degrees:
    X_poly = PolynomialFeatures(degree=degree).fit_transform(X)
    model = sm.OLS(y, X_poly).fit()
    models.append(model)

# find the optimal degree using cross validation
optimal_degree = degrees[np.argmin(cv_scores)]
print(f"Optimal degree using 5-fold cross validation: {optimal_degree}")

# find the optimal degree using ANOVA
anova_df = anova_lm(*models)
optimal_degree_anova = degrees[anova_df[anova_df['Pr(>F)'] < 0.05].index[-1]]
print(f"Optimal degree using ANOVA: {optimal_degree_anova}")

print(f'ANOVA results:\n{anova_df}')
# Out:
# Optimal degree using 5-fold cross validation: 4
# Optimal degree using ANOVA: 3
# ANOVA results:
#    df_resid           ssr  df_diff        ss_diff           F        Pr(>F)
# 0    2998.0  5.022216e+06      0.0            NaN         NaN           NaN
# 1    2997.0  4.793430e+06      1.0  228786.010128  143.518660  2.449925e-32
# 2    2996.0  4.777674e+06      1.0   15755.693664    9.883629  1.683871e-03
# 3    2995.0  4.771604e+06      1.0    6070.152124    3.807838  5.110635e-02
# 4    2994.0  4.770322e+06      1.0    1282.563017    0.804558  3.698061e-01
# 5    2993.0  4.766389e+06      1.0    3932.257499    2.466726  1.163856e-01
# 6    2993.0  4.764599e+06     -0.0    1790.481752        -inf           NaN
# 7    2993.0  4.764136e+06     -0.0     462.460746        -inf           NaN
# 8    2993.0  4.764981e+06     -0.0    -844.190096         inf           NaN
# 9    2993.0  4.771202e+06     -0.0   -6221.386832         inf           NaN

# %%
# create visualization
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 12))

# left plot: CV error by degree
ax1.plot(degrees, cv_scores, marker='o', linewidth=2, markersize=8)
ax1.axvline(optimal_degree, color='red', linestyle='--', 
            label=f'Optimal degree = {optimal_degree}')
ax1.set_xlabel('Degree')
ax1.set_ylabel('Cross-validated MSE')
ax1.set_title('CV Error by Polynomial Degree', fontsize=12)
ax1.set_xticks(degrees)
ax1.legend()

# right plot: fitted polynomial with optimal degree
final_model = Pipeline([
    ('poly', PolynomialFeatures(degree=optimal_degree)),
    ('linear', LinearRegression())
])
final_model.fit(X, y)
# use statsmodels OLS to get 95% prediction interval
X_poly = final_model.named_steps['poly'].transform(X)
model_sm = sm.OLS(y, X_poly).fit()
age_range = np.linspace(X.min(), X.max(), 100).reshape(-1, 1)
age_range_poly = final_model.named_steps['poly'].transform(age_range)
preds = model_sm.get_prediction(age_range_poly)
preds_mean = preds.predicted_mean
preds_ci = preds.conf_int(alpha=0.05)

ax2.scatter(X, y, alpha=0.5, s=10, label='Data', color='gray')
for val, fmt in zip([preds_mean, preds_ci[:, 0], preds_ci[:, 1]], ['b', 'r--', 'r--']):
    ax2.plot(age_range, val, fmt, linewidth=2)
ax2.set_xlabel('Age')
ax2.set_ylabel('Wage')
ax2.set_title('Polynomial Regression', fontsize=12)
ax2.legend()
plt.show()

# %% [markdown]
# ### 6.b
# Using 5-fold cross validation, the number of knots resulting in the smallest MSE is 10. However, the plot of *CV MSE by number of knots* shows that it is not necessary to use 10 knots. In particular, the plot shows a drastic decrease in CV MSE as the number of knots increases from 1 to 2 (from above 12000 to below 2000). As the number of cuts increases from 2 to 10, the CV MSE decreases minimally. From 6 to 10 cuts, the CV MSE appears to plateau.
#
# Therefore, an optimal number of knots is around 2 to 5.

# %%
n_cuts_range = range(1, 11)
cv_scores_step = []

# 5-fold cross validation to find optimal number of cuts
for n_cuts in n_cuts_range:
    age_cuts = pd.qcut(X.reshape(-1), q=n_cuts)
    model = Pipeline([
        ('onehot', OneHotEncoder()),
        ('linear', LinearRegression())
    ])
    scores = cross_val_score(model, age_cuts.reshape(-1, 1), y, cv=cv, scoring='neg_mean_squared_error')
    cv_scores_step.append(-scores.mean())

# find optimal number of cuts
optimal_n_cuts = n_cuts_range[np.argmin(cv_scores_step)]
print(f"Optimal number of cuts: {optimal_n_cuts}")
# Out:
# Optimal number of cuts: 10

# %%
optimal_n_cuts = 5

# fit the step function with the optimal number of cuts
age_bins_final = pd.cut(X.reshape(-1), bins=optimal_n_cuts, labels=False)
X_binned_final = age_bins_final.reshape(-1, 1)
final_model_step = Pipeline([
    ('onehot', OneHotEncoder()),
    ('linear', LinearRegression())
])
final_model_step.fit(X_binned_final, y)

# create prediction visualization
age_range = np.linspace(X.min(), X.max(), 100)
age_bins_pred = pd.cut(age_range, bins=optimal_n_cuts, labels=False)
X_binned_pred = age_bins_pred.reshape(-1, 1)
preds = final_model_step.predict(X_binned_pred)

# create visualization
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 12))

# left plot: CV error by number of cuts
ax1.plot(n_cuts_range, cv_scores_step, marker='o', linewidth=2, markersize=8)
ax1.axvline(optimal_n_cuts, color='red', linestyle='--', 
            label=f'Optimal number of cuts = {optimal_n_cuts}')
ax1.set_xlabel('Number of cuts')
ax1.set_ylabel('Cross-validated MSE')
ax1.set_title('CV Error by Number of Cuts', fontsize=12)
ax1.set_xticks(n_cuts_range)
ax1.legend()

# right plot: fitted step function with optimal number of cuts
ax2.scatter(X, y, alpha=0.5, s=10, label='Data', color='gray')
ax2.plot(age_range, preds, color='blue', linewidth=2, label=f'Step function (n_cuts = {optimal_n_cuts})')
ax2.set_xlabel('Age')
ax2.set_ylabel('Wage')
ax2.set_title('Step Function', fontsize=12)
ax2.legend()
plt.show()

# %% [markdown]
# ## Exercise 7
#
# Explore the relationship between the following variables: *age, maritl, jobclass* to predict *wage*. The model is a GAM with the following form:
# $$
# wage = \beta_0 + \beta_1f(age) + \beta_2 f(maritl) + \beta_3 f(jobclass)
# $$
# Since *age* is a continuous variable, we can use a smoothing spline. Since *maritl* and *jobclass* are categorical, we can use factor terms.
#
# The plot of the partial effects of *age, maritl, jobclass* on *wage* are shown below:
# * The plot of the partial effect of *age* shows that people with below around 25 years of age have lower salary on average. Between the age 18 to 40, as people get older, their salary increases. Salary peaks for people in their 40s and around 60, receicing about 10,000 monetary unit above average. Once people reach 60, their salary declines over the year, reaching the average amount again around late 60s, thenceforth decreasing to below average. The 95% confidence interval shows that the prediction have high variance at the two age boundaries, especially around 80s, indicating that there are few observations at these two boundary for the model to infer the true relationship.
# * The plot of the partial effect of *maritl* shows that married people have significantly higher salary than the other maritial status, by approximately around 12,500 monetary unit. People in the remaining 4 maritial status have lower than average salary, although they are not statistically distinguishable from the mean as their confidence intervals overlap 0. The 95% confidence interval for status *3.widowed* and *5.Separated* are significantly high, indicating that there are few observations for people in these 2 categories for the model to confidently infer the true relationship.
# * The plot of the partial effect of *jobclass* shows that people in the information class have significantly higher salary than the other job classes, by approximately around 7500 monetary unit. People in the industrial class have lower than the average salary by 7500 monetary unit. The 95% confidence interval for these 2 classes are rather small, indicating that there are sufficient observations in both classes for the model to infer the true relationship.

# %%
# prepare data
X_age = Wage['age']
X_maritl = Wage['maritl'].cat.codes
X_jobclass = Wage['jobclass'].cat.codes
X = np.column_stack([X_age, X_maritl, X_jobclass])

# fit the GAM model
gam = LinearGAM(s_gam(0) + f_gam(1, lam=0) + f_gam(2, lam=0)).fit(X, y)

# %%
# visualize the partial effects

fig, axes = plt.subplots(3, 1, figsize=(8, 15))

# age
XX_age = np.linspace(X_age.min(), X_age.max(), 100).reshape(-1, 1)
XX = gam.generate_X_grid(term=0, n=len(XX_age))
XX[:, 0] = XX_age.reshape(-1)
# compute the partial dependance and the 95% CI
preds_age, confi_age = gam.partial_dependence(term=0, X=XX, width=0.95)
# re-center the data around the mean
center_age = preds_age.mean()
preds_age -= center_age
confi_age -= center_age
axes[0].plot(XX_age, preds_age, 'b', linewidth=3, label='Partial Effect of Age')
axes[0].plot(XX_age, confi_age[:, 0], 'r--', linewidth=3, label='95% CI')
axes[0].plot(XX_age, confi_age[:, 1], 'r--', linewidth=3)
axes[0].set_xlabel('Age')
axes[0].set_ylabel('Effect of Age')
axes[0].set_title('Partial dependence of Age on Wage', fontsize=12)
axes[0].legend()

# maritl
maritl_labels = Wage['maritl'].cat.categories
maritl_codes = np.arange(len(maritl_labels))
XX_maritl = gam.generate_X_grid(term=1, n=len(maritl_labels))
preds_maritl, confi_maritl = gam.partial_dependence(term=1, X=XX_maritl, width=0.95)
center_martil = preds_maritl.mean()
preds_maritl -= center_martil
confi_maritl -= center_martil
yerr_lower = preds_maritl - confi_maritl[:, 0]
yerr_upper = confi_maritl[:, 1] - preds_maritl
axes[1].bar(maritl_codes, preds_maritl, label='Partial Effect of Marital Status')
axes[1].errorbar(maritl_codes, preds_maritl, yerr=[yerr_lower, yerr_upper], fmt='none', capsize=5, label='95% CI', ecolor='black')
axes[1].set_xlabel('Marital Status')
axes[1].set_ylabel('Effect of Marital Status')
axes[1].set_title('Partial dependence of Marital Status on Wage', fontsize=12)
axes[1].set_xticks(maritl_codes)
axes[1].set_xticklabels(maritl_labels, rotation=45, ha='right')
axes[1].legend()

# jobclass
jobclass_labels = Wage['jobclass'].cat.categories
jobclass_codes = np.arange(len(jobclass_labels))
XX_jobclass = gam.generate_X_grid(term=2, n=len(jobclass_labels))
preds_jobclass, confi_jobclass = gam.partial_dependence(term=2, X=XX_jobclass, width=0.95)
center_jobclass = preds_jobclass.mean()
preds_jobclass -= center_jobclass
confi_jobclass -= center_jobclass
yerr_lower = preds_jobclass - confi_jobclass[:, 0]
yerr_upper = confi_jobclass[:, 1] - preds_jobclass
axes[2].bar(jobclass_codes, preds_jobclass, label='Partial Effect of Job Class')
axes[2].errorbar(jobclass_codes, preds_jobclass, yerr=[yerr_lower, yerr_upper], fmt='none', capsize=5, label='95% CI', ecolor='black')
axes[2].set_xlabel('Job Class')
axes[2].set_ylabel('Effect of Job Class')
axes[2].set_title('Partial dependence of Job Class on Wage', fontsize=12)
axes[2].set_xticks(jobclass_codes)
axes[2].set_xticklabels(jobclass_labels, rotation=45, ha='right')
axes[2].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Exercise 9
# ### 9.a
# The cubic polynomial regression has the form $$\hat{y}_i = \hat{\beta}_0 + \hat{\beta}_1P_1(x_i) + \hat{\beta}_2P_2(x_i) + \hat{\beta}_3P_3(x_i)$$
#
# Where:
# * $\hat{\beta}_0 = 0.555$
# * $\hat{\beta}_1 = -2.003$
# * $\hat{\beta}_2 = 0.856$
# * $\hat{\beta}_3 = -0.318$
#
# The t-statistics value of each coefficient are high, with their corresponding p-value ~ 0.000. Furthermore, their respective confidence interval does not include 0. Thus, the null hypothesis that the coefficients are equal to zero is rejected.
#
# The R-squared value of the cubic polynomial regression is 0.715, indicating that the model accounts for 71.5% of the variance in the response variable. The F-statistic value is high, 419.3, with a low p-value, ~ 0.000. The F-test suggests that there is a strong statistical relationship between the predictors and the response variable.
#
# The plot of the cubic polynomial regression shows that the cubic polynomial regression model closely mirror the relationship between the predictors and the response variable. This is a strong indication that the cubic polynomial regression model offers good predictive power to the response variable in the training data.
#
# In summary, the cubic polynomial regression model offers sufficiently good explanatory and predictive power to the response variable in the training data.

# %%
Boston = load_data('Boston')
y = Boston['nox']
X = Boston['dis']

# a
# fit cubic model using poly
poly_dis = MS([poly('dis', degree=3)]).fit(Boston)
model = sm.OLS(y, poly_dis.transform(Boston)).fit()
display(model.summary())

# visualize the fit
x_vis = np.linspace(Boston['dis'].min(), Boston['dis'].max(), 100)
preds = model.get_prediction(poly_dis.transform(pd.DataFrame({'dis': x_vis})))
conf_int = preds.conf_int(alpha=0.05)

fig, ax = plt.subplots(figsize=(8, 6))
ax.scatter(X, y, c='gray',alpha=0.5)
for val, ls in zip([preds.predicted_mean, conf_int[:, 0], conf_int[:, 1]], ['b-', 'r--', 'r--']):
    ax.plot(x_vis, val, ls)
ax.set_xlabel('Distance to employment center')
ax.set_ylabel('Nitric oxide concentration')
ax.set_title('Nitric oxide concentration vs distance to employment center')
plt.show()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    nox   R-squared:                       0.715
# Model:                            OLS   Adj. R-squared:                  0.713
# Method:                 Least Squares   F-statistic:                     419.3
# Date:                Mon, 26 Jan 2026   Prob (F-statistic):          2.71e-136
# Time:                        18:07:46   Log-Likelihood:                 690.44
# No. Observations:                 506   AIC:                            -1373.
# Df Residuals:                     502   BIC:                            -1356.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### 9.b
# The plot of *MSE vs degrees of the polynomial* shows that as the degrees of the polynomial increases, the MSE monotonically decreases. This is rather expected as these are nested models, where higher-degree models contain all the terms in the lower-degree ones, plus higher-order terms. In particular, as the model changes from degree 1 to degree 2, the MSE decreases from 5.5e-3 to 4.0e-3 - the largest decrease. From degree 2 to degree 3, the MSE decreases from 4.0e-3 to 3.9e-3 - the second largest decrease. There is a sharp elbow observed at degree 3. From degree 3 to 4, the MSE infinitestimally increases. From degree 4 onwards, the MSE marginally decreases. Most notably, from degree 8 to degree 10, the MSE seems to plateau.
#
# The plot of *Nitric oxide concentration vs Distance to employment center* for different polynomial degrees shows the fit of each model to the training data. As the degree 1 model is a straighline whereas the data points demonstrate a non-linear behavior, the degree-1 model shows a high bias, making it fail to capture the relationship between the two variables. From degree 2 onwards, the models show decreasing bias, making them better at capturing the non-linear relationship between the two variables. However, from degree-5 polynomial model onwards, the models show increasing variance through their oscilatory behaviors at the boundaries of the data, making them overfit to the noise in the training data.
#
# The above two plots agree with each other. The degree-3 and degree-4 models have a relatively low MSE compared to the degree-1 and degree-2 models, while not showing overfitting behavior on the training data. From the degree-5 polynomial model onwards, the MSE gradually decreases due to the model becoming overfitting to the training data. The results suggest that a degree 3 and 4 polynomials offer a good bias-variance trade-off on the training data.

# %%
# 9.b

x_vis = np.linspace(Boston['dis'].min(), Boston['dis'].max(), 100)
degrees = range(1, 11)
MSE_ = np.empty(len(degrees))

fig, axes = plt.subplots(2, 1, figsize=(6, 10))

for degree in degrees:
    poly_dis = MS([poly('dis', degree=degree)]).fit(Boston)
    model = sm.OLS(y, poly_dis.transform(Boston)).fit()
    # plot fitted model
    preds = model.get_prediction(poly_dis.transform(pd.DataFrame({'dis': x_vis})))
    axes[1].plot(x_vis, preds.predicted_mean, label=f'{degree}')
    # calculate training MSE
    preds = model.get_prediction()
    MSE_[degree-1] = model.mse_resid

axes[0].plot(degrees, MSE_, marker='o', label='Training MSE')
axes[0].set_xlabel('Polynomial degree')
axes[0].set_ylabel('Training MSE')
axes[0].set_title('Training MSE vs Polynomial degree')
axes[0].legend()

axes[1].scatter(X, y, c='gray',alpha=0.5)
axes[1].legend(title='Polynomial degree')  
axes[1].set_xlabel('Distance to employment center')
axes[1].set_ylabel('Nitric oxide concentration')
axes[1].set_title('Nitric oxide concentration vs Distance to employment center')


plt.tight_layout()
plt.show()

# %% [markdown]
# ### 9.c
# The cross-validated MSE on the training data is significantly higher than the training MSE, which is as expected.
#
# The shape of the plot of the *cross-validated MSE vs the polynomial degree* is drastically different from the plot of the *training MSE vs the polynomial degree*. In particular, from degree 1 to degree 3, the cross-validated MSE drops from approximately 6.0e-3 to its minimum at approximately 3.5e-3. From degree 3 to degree 4, the cross-validated MSE minimally increases. From degree 4 to degree 7, the cross-validated MSE gradually increases to 7.0e-3, then slightly degree at degree 8 before reaching its peak at degree 9 (22.5e-3). Finally, it drops to around 5.0e-3 at degree 10. The fluctations of the model from degree 7 to degree 10 implies the models' susceptibility to high variance at higher polynomial degrees.
#
# The behavior of the cross-validated MSE suggests that as the degree-1 and degree-2 models underfit. At degree 3 and 4, the models reach their optimal bias-variance trade-off. From degree 5 to degree 10, are susceptible to overfitting and high variance.

# %%
# 9.c
# use cross-validation

degrees = range(1, 11)
cv_scores = []
cv = KFold(n_splits=5,
           shuffle=True,
           random_state=0)

# perform 5 fold cross validation for each degree
for degree in degrees:
    model = Pipeline([
        ('poly', PolynomialFeatures(degree=degree)),
        ('linear', LinearRegression())
    ])
    cv_results = cross_val_score(model, X.values.reshape(-1, 1), y.values.reshape(-1, 1), cv=cv, scoring='neg_mean_squared_error')
    cv_scores.append(-cv_results.mean())

# %%
optimal_degree = degrees[np.argmin(cv_scores)]

# create visualization
fig, ax = plt.subplots( figsize=(6, 4))

# first plot: CV error by degree
ax.plot(degrees, cv_scores, marker='o', linewidth=2, markersize=8)
ax.axvline(optimal_degree, color='red', linestyle='--', 
            label=f'Optimal degree = {optimal_degree}')
ax.set_xlabel('Degree')
ax.set_ylabel('Cross-validated MSE')
ax.set_title('CV Error by Polynomial Degree', fontsize=12)
ax.set_xticks(degrees)
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 9.d
#
# There are several ways to define the number of knots, for intance:
# * varying the polynomial power of the model, resulting in varying number of knots
# * specifying the number of knots, or the specific knots
# * specifying the degrees of freedom of the model
# * etc.
#
# In the previous sections, cubic (degree-3) model is at the optimal point of bias-variance tradeoff. Therefore, a cubic spline model is selected in this section. A cubic spline regression model with $K$ knots uses $K + 3$ degrees of freedom and an intercept. Since the model has 4 degrees of freedom, it has $4-3=1$ knot. Given the parameter $df$, the bs() function automatically places the knowts at uniform quantile of $dis$. The one knot in the model is, therefore, at the median of $dis$. So, the knot is at $dis=3.207$.
#
# The model has the form: $$\hat{y} = \beta_0 + \beta_1P_1(dis) + \beta_2P_2(dis)+ \beta_3P_3(dis) + \beta_4P_4(dis,\xi)$$
#
# where $\xi$ is the knot
#
# The model has R squared value at 0.716, indicating that 71.6% of the variance in $nox$ is explained by the model. The F-statistic is high (316.5), with an infinitesimal p-value (~0.000). These signs indicate that there is a statistically strong relationship between $dis$ and $nox$.
#
# The plot of the model on the training data shows that the model fits rather well with the shape of the data, suggesting that the cubic spline model is a good fit for the training data.
#
# In summary, a cubic spline model with 4 degrees of freedom offers a suffcient explanatory and predictive power to the training data.

# %%
bs_dis = MS([bs('dis', df=4, degree=3, name='bs(dis)')])
Xbs = bs_dis.fit_transform(Boston)
model = sm.OLS(y, Xbs).fit()
display(model.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    nox   R-squared:                       0.716
# Model:                            OLS   Adj. R-squared:                  0.714
# Method:                 Least Squares   F-statistic:                     316.5
# Date:                Mon, 26 Jan 2026   Prob (F-statistic):          1.39e-135
# Time:                        18:07:46   Log-Likelihood:                 691.93
# No. Observations:                 506   AIC:                            -1374.
# Df Residuals:                     501   BIC:                            -1353.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.7345      0.015     50.306      0.000       0.706       0.763
# ...

# %%
fig, ax = plt.subplots(figsize=(8, 6))

ax.scatter(X, y, c='gray',alpha=0.5)  
ax.set_xlabel('Distance to employment center')
ax.set_ylabel('Nitric oxide concentration')
ax.set_title('Nitric oxide concentration vs Distance to employment center')

preds = model.get_prediction(bs_dis.transform(pd.DataFrame({'dis': x_vis})))
conf_int = preds.conf_int(alpha=0.05)
for val, ls, label_ in zip([preds.predicted_mean, conf_int[:, 0], conf_int[:, 1]], \
    ['b-', 'r--', 'r--'], ['Predicted mean', 'Lower CI', 'Upper CI']):
    ax.plot(x_vis, val, ls, label=label_)

# retrive the internal knots and plot them
knots = BSpline(df=4).fit(Boston['dis']).internal_knots_
for knot in knots:
    ax.axvline(x=knot, color='k', linestyle='--', label='Internal knots')

ax.legend();
print("Internal knot: ", knots)
# Out:
# Internal knot:  [3.20745]

# %% [markdown]
# ### 9.e
#
# While the degrees of freedom varies in the range $[3, 11)$, the basic functions are piecewise cubic polynomials (Cubic Splines), since cubic polynomials shows that it offers the best bias-variance trade-off in the previous sections.
#
# The plot *Training RSS vs degrees of freedom* shows that generally, as the number of degrees of freedom (df) increases, the training RSS decreases. At $df=3$, the model has 0 knots, making it the cubic polynomial regression. The most significant plumet is from $df=4$ (1.92) to $df=5$ (1.84). As the df increases from 5 to 8, the training RSS gradually decreases to 1.82, then slighly increases to 1.83 at $df=9$, and finally decreases to 1.79 at $df=10$. The RSS then slightly increases at $df=11$ to 1.80, and then gradually decreases to 1.78 at $df=13$. The fluctuation from $df=7$ to $df=12$ could be due to the fact that as the knots are dynamically and automatically selected based on the specified degrees of freedom (hence, these models are not nested models), the knots at $df=9$ and $df=11$ might not perfectly align with the structural breaks in the training data.
#
# The plot of the models with varying degrees of freedom on the data shows that the model with $df=3$ and $df=4$ are the simplest models that fits the overall shape of the data sufficiently well. The model with $df=5$ might significantly reduce RSS since it is more flexible, thus gaining more accuracy on the left-side tail of the data. From models with $df=6$ to $df=113$, the models show more complex curvatures, indicating they are increasingly prone to overfitting of the training data. This is reasonaly since with higher degrees of freedoms, the bias of these models decreases while the variances increases, making the models more flexible to fit the training data and prone to overfitting.
#
# In summary, the model with $df=3$ and $df=4$ offer a balance for the bias-variance trade-off and having a satisfying parsimony. On the other hand, model with $df=5$ offers the best drop in training RSS, making it still a strong contender for the best model.

# %%
degrees_of_freedom = np.arange(3, 14)
RSS_ = np.empty(len(degrees_of_freedom))

fig, axes = plt.subplots(2, 1, figsize=(6, 10))

for degree in degrees_of_freedom:
    bs_dis = MS([bs('dis', df=degree, name='bs(dis)')])
    Xbs = bs_dis.fit_transform(Boston)
    model = sm.OLS(y, Xbs).fit()
    # plot fitted model
    preds = model.get_prediction(bs_dis.transform(pd.DataFrame({'dis': x_vis})))
    axes[1].plot(x_vis, preds.predicted_mean, label=f'{degree}')
    # calculate training MSE
    preds = model.get_prediction()
    RSS_[degree-3] = model.ssr

axes[0].plot(degrees_of_freedom, RSS_, marker='o', label='Training RSS')
axes[0].set_xlabel('Degrees of freedom')
axes[0].set_ylabel('Training RSS')
axes[0].set_title('Training RSS vs degrees of freedom')
axes[0].legend()

axes[1].scatter(X, y, c='gray',alpha=0.5)
axes[1].legend(title='Degrees of freedom')  
axes[1].set_xticks(degrees_of_freedom)
axes[1].set_xlabel('Distance to employment center')
axes[1].set_ylabel('Nitric oxide concentration')
axes[1].set_title('Nitric oxide concentration vs Distance to employment center')


plt.tight_layout()
plt.show()

# %% [markdown]
# ### 9.f
# The basic functions are piecewise cubic polynomials. So, $df = K + 3$, where $K$ is the number of knots.
#
# The sklearn.model_selection.cross_val_score class is used to calculate the cross-validated RSS for varyring degrees of freedom. The sklearn.preprocessing.SplineTransformer is used to transform the data to match the varying degrees of freedom of spline basis functions. Since the SplineTransformer only works on $K \geq 2$, the cross-validation can only be performed for $df \geq 5$.
#
# Since $df=3$ is the equivalent of a cubic polynomial (since $K=3-3=0$), the cross-validated RSS is the same as that of the cubic polynomial model.
#
# The shape of the plot of *Cross-validated RSS by degrees of freedom* differs from that of the one on training data. In particular, the RSS of the cross-validated data is higher than the training RSS, which is because the cross-validated models are tested on unseen data. The RSS of the model with $df=3$ is around 1.94, but is slighly higher than models with $df=5$, $df=6$, $df=7$. From $df=7$ to $df=10$, the RSS decreases from 1.94 to its minimum at 1.88. From $df=10$ to $df=13$, the RSS increases from 1.88 to its maximum at 1.92. However, compared to the values of RSS on training data, these fluctuations are less pronounced.
#
# Although the cross-validated RSS shows that among models with $df \geq 5$, the model with $df=10$ offers the best predictive power on unseen data. However, given the small difference in RSS between $df=10$ and $df=3$, the model with $df=3$ is preferred since it can achieve somewhat similar performance with much less complexity.

# %%
# retrieve CV RSS of model with df=3

model = Pipeline([
        ('poly', PolynomialFeatures(degree=3)),
        ('linear', LinearRegression())
    ])
cv_results = cross_val_score(model, X.values.reshape(-1, 1), y.values.reshape(-1, 1), cv=cv, scoring='neg_mean_squared_error')
cv_score_df3 = -cv_results.mean() * Boston.shape[0]

# %%
cv_scores = [cv_score_df3, np.nan]
cv = KFold(n_splits=5,
           shuffle=True,
           random_state=0)
n_knots = degrees_of_freedom[2:] - 3
n = Boston.shape[0]
# perform 5 fold cross validation for each degree
for n_knot in n_knots:
    model = Pipeline([
        ('spline', SplineTransformer(n_knots=n_knot)),
        ('linear', LinearRegression())
    ])
    cv_results = cross_val_score(model, X.values.reshape(-1, 1), y.values.reshape(-1, 1), cv=cv, scoring='neg_mean_squared_error')
    # RSS = n * MSE
    cv_scores.append(-cv_results.mean() * n)

# %%
optimal_degree = degrees_of_freedom[np.nanargmin(cv_scores)]

# create visualization
fig, ax = plt.subplots( figsize=(6, 4))

# first plot: CV error by degree
ax.plot(degrees_of_freedom, cv_scores, marker='o', linewidth=2, markersize=8)
ax.axvline(optimal_degree, color='red', linestyle='--', 
            label=f'Optimal degree = {optimal_degree}')
ax.set_xlabel('Degrees of Freedom')
ax.set_ylabel('Cross-validated RSS')
ax.set_title('CV RSS by Degrees of Freedom', fontsize=12)
ax.set_xticks(degrees_of_freedom)
ax.legend()
plt.tight_layout()
plt.show()
